# %% [markdown]
# # How to Open Machine Learning Input Products

# %% [markdown]
# For each detectid in the line emission database (detect_hdr2.h5) we have generated 100 pixel (200 Angstrom) by 9 pixel fiber cutouts of the weighted sum of all fibers used to measured the extracton as well as cutouts of the four brightest fibers contributing to the flux. We also include the 1D spectrum (this is the same product included in the Spectra table for the detect_hdr2.h5 file) and a 30 arcsec x 30 arcsec cutout of HSC r-band imaging for the detection in available.

# %%
import tables as tb
import numpy as np
import os.path as op

from astropy.table import Table, join, unique
import astropy.units as u

import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.visualization import ZScaleInterval

from hetdex_api.config import HDRconfig

# %%
config = HDRconfig('hdr5')

# %% [markdown]
# ## Pytables and hetdex_api.config provide an easy interface to the ML products

# %% [markdown]
# Labels are in:

# %%
labelfile = op.join( config.hdr_dir['hdr5'], 'catalogs','ml','ml-labels_3.0.0.tab')
label_tab = Table.read(labelfile, format='ascii')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 labelfile = op.join( config.hdr_dir['hdr5'], 'catalogs','ml','ml-labels_3.0.0.tab')
# ----> 2 label_tab = Table.read(labelfile, format='ascii')
#
# File /opt/conda/lib/python3.12/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/registry/core.py:221, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     218         kwargs.update({"filename": path})
#     220 reader = self.get_reader(format, cls)
# --> 221 data = reader(*args, **kwargs)
#     223 if not isinstance(data, cls):
#     224     # User has read with a subclass where only the parent class is
#     225     # registered.  This returns the parent class, so try coercing
#     226     # to desired subclass.
#     227     try:
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/ascii/connect.py:19, in io_read(format, filename, **kwargs)
#      17     format = re.sub(r"^ascii\.", "", format)
#      18     kwargs["format"] = format
# ---> 19 return read(filename, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/ascii/ui.py:436, in read(table, guess, **kwargs)
#     430             new_kwargs["guess_html"] = _probably_html(table)
#     432 # Get the table from guess in ``dat``.  If ``dat`` comes back as None
#     433 # then there was just one set of kwargs in the guess list so fall
#     434 # through below to the non-guess way so that any problems result in a
#     435 # more useful traceback.
# --> 436 dat = _guess(table, new_kwargs, format, fast_reader)
#     437 if dat is None:
#     438     guess = False
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/ascii/ui.py:681, in _guess(table, read_kwargs, format, fast_reader)
#     675 if table_guess_subset:
#     676     # First try with subset of lines - if this fails we can skip this
#     677     # format early. If it works, we still proceed to check with the
#     678     # full table since we need to then return the read data.
#     679     reader.read(table_guess_subset)
# --> 681 dat = reader.read(table)
#     682 _read_trace.append(
#     683     {
#     684         "kwargs": copy.deepcopy(guess_kwargs),
#    (...)
#     688     }
#     689 )
#     690 return dat
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/ascii/core.py:1432, in BaseReader.read(self, table)
#    1429     newline = None
#    1431 # Get a list of the lines (rows) in the table
# -> 1432 self.lines = self.inputter.get_lines(table, newline=newline)
#    1434 # Set self.data.data_lines to a slice of lines contain the data rows
#    1435 self.data.get_data_lines(self.lines)
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/ascii/core.py:342, in BaseInputter.get_lines(self, table, newline)
#     336 try:
#     337     if (
#     338         hasattr(table, "read")
#     339         or isinstance(table, os.PathLike)
#     340         or ("\n" not in table + "" and "\r" not in table + "")
#     341     ):
# --> 342         with get_readable_fileobj(table, encoding=self.encoding) as fileobj:
#     343             table = fileobj.read()
#     344     if newline is None:
#
# File /opt/conda/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/conda/lib/python3.12/site-packages/astropy/utils/data.py:364, in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers, use_fsspec, fsspec_kwargs, close_files)
#     355 if is_url:
#     356     name_or_obj = download_file(
#     357         name_or_obj,
#     358         cache=cache,
#    (...)
#     362         http_headers=http_headers,
#     363     )
# --> 364 fileobj = io.FileIO(name_or_obj, "r")
#     365 if is_url and not cache:
#     366     delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/Hobby-Eberly-Telesco/hdr5/catalogs/ml/ml-labels_3.0.0.tab'

# %%
t = Table( np.unique(label_tab['detectid'], return_counts=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t = Table( np.unique(label_tab['detectid'], return_counts=True))
#
# NameError: name 'label_tab' is not defined

# %%
t_uniq = unique( label_tab, keys='detectid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 t_uniq = unique( label_tab, keys='detectid')
#
# NameError: name 'label_tab' is not defined

# %%
label_tab[ label_tab['detectid'] == 3012833523]
# Out:
# <Table length=1>
#  detectid     shotid   label
#   int64       int64     str9
# ---------- ----------- ------
# 3012833523 20210530016 meteor

# %%
t.sort('col1')
t.reverse()
t[100:150]
# Out:
# <Table length=50>
#  detectid   col1
#   int64    int64
# ---------- -----
# 3004744983     1
# 3004744985     1
# 3004745009     1
# 3004745010     1
# 3004745011     1
# 3004744815     1
# 3004745013     1
# 3004745014     1
# 3004745015     1
# 3004745016     1
#        ...   ...
# 3004744491     1
# 3004744493     1
# 3004744499     1
# 3004744342     1
# 3004744323     1
# 3004744528     1
# 3004744262     1
# 3004744190     1
# 3004744193     1
# 3004744195     1

# %%
Table( np.unique( label_tab['label'], return_counts=True))
# Out:
# <Table length=5>
#   label     col1
#    str9    int64
# --------- -------
#        -- 1560135
#    badamp   10000
#    badpix   10000
# confirmed    9505
#    meteor    6838

# %%
Table( np.unique( t_uniq['label'], return_counts=True))
# Out:
# <Table length=5>
#   label     col1
#    str9    int64
# --------- -------
#        -- 1560135
#    badamp   10000
#    badpix    9971
# confirmed    9505
#    meteor    6827

# %%
mlfile = op.join( config.hdr_dir['hdr3'], 'catalogs','ml','detect_ml_3.0.0.h5')
fileh = tb.open_file(mlfile, 'r') 

print('ML data product file is found at {}'.format(mlfile))
# Out:
# ML data product file is found at /home/jovyan/Hobby-Eberly-Telesco/hdr3/catalogs/ml/detect_ml_3.0.0.h5

# %% [markdown]
# Here is the hierarchical structure:

# %%
specdata = fileh.root.Spec1D.read()

# %% [markdown]
# # Open the 2 Summed Fiber Image

# %% [markdown]
# Because we have over 1 million detections in each table and each table contains several 2D arrays, the best way to navigate the file is by detectid. We have indexed all three tables based on the detectid so it is fast to query. But we do suggest you do it one by one. Please do not make copies of every component of this file on TACC anywhere on /work. Ideally you should learn to use the h5 files, otherwise pick smaller subsets of detections to work with.

# %%
mlfile = op.join( config.hdr_dir['hdr5'], 'catalogs','ml','detect_ml_5.0.0.h5')
fileh = tb.open_file(mlfile, 'r')
detectid_obj = 3000001176

# %%
fileh.root
# Out:
# / (RootGroup) ''
#   children := ['FiberImages' (Table), 'LineImages' (Table), 'PhotImages' (Table), 'Spec1D' (Table)]

# %%
table = fileh.get_node('/FiberImages')
detect_ids = table.col('detectid')
detect_ids.size
# Out:
# 304280

# %%
detect_ids
# Out:
# array([5000002829, 5000002830, 5000002837, ..., 5003908494, 5003908496,
#        5003908497])

# %%
# Choose a random source
ind = np.random.choice(detect_ids, 1)
obj_data = fileh.root.FiberImages.read_where(f'detectid == {str(ind[0])}')[0]

# Plot
height=9 # in pixels
detectid = obj_data['detectid']
wave = obj_data['im_wave']
im_sum = obj_data['im_sum'] # this is the 2D summed image, 1st dim is height in fiber dims, 2nd dim is wave dim
im_array = obj_data['im_array'] # this is the 4 brightest fibers, 1st dim is fibers, 2nd dim is fiber dims, 3rd is wavelength
zscale = ZScaleInterval(contrast=0.5,krej=2.5)
vmin, vmax = zscale.get_limits(values=im_sum)
plt.figure(figsize=(12,5))
plt.imshow(im_sum,vmin=vmin, vmax=vmax,extent=[wave[0], wave[-1], -int(height/2.), int(height/2.)], origin="lower",cmap=plt.get_cmap('gray'),interpolation="none")
plt.show()

# %%
# grab random 10K fiber images
rng = np.random.default_rng()
sel_random = rng.integers(len(fileh.root.FiberImages), size=10000)

# %%
im_array_table = Table(fileh.root.FiberImages.read())

# %%
im_array_table[sel_random]
# Out:
# <Table length=10000>
#  detectid         im_wave         ...         im_array
#   int64         float32[100]      ...     float32[4,9,100]
# ---------- ---------------------- ... ------------------------
# 5002183507 4817.2007 .. 5011.6104 ... -11.848277 .. -1.0484352
# 5000700305   3907.5383 .. 4104.73 ...  -3.6192474 .. 1.1094706
# 5002952511  4580.097 .. 4777.0176 ...    7.319313 .. 2.9831371
# 5003158163 5276.9214 .. 5462.6484 ...  -1.633915 .. -3.1823492
# 5000046934  4002.3672 .. 4199.885 ...   -9.218357 .. -2.246639
# 5001433054   4948.974 .. 5141.768 ...  3.605361 .. -0.44722795
# 5000853728       0.0 .. 3677.0386 ...         0.0 .. 1.5568774
# 5003046689  3995.8713 .. 4194.639 ...  3.1568284 .. -2.4769762
# 5003746135        0.0 .. 3624.111 ...        0.0 .. -1.5769517
#        ...                    ... ...                      ...
# 5002985907  4862.591 .. 5054.7617 ...   2.4938583 .. -1.160593
# 5002584725       5374.4043 .. 0.0 ...        -16.490036 .. 0.0
# 5000862077       0.0 .. 3673.3784 ...         0.0 .. -2.093262
# 5003586856 4000.8242 .. 4198.3076 ...   -7.449474 .. 6.7825785
# 5001618927   4832.518 .. 5026.232 ...         6.0288124 .. 0.0
# 5000290852  5176.189 .. 5365.2354 ...  1.9157662 .. -2.1251812
# 5001456812  3639.983 .. 3838.0593 ...  -2.6730106 .. -6.649328
# 5000894844 4249.5474 .. 4446.7695 ...   3.5159693 .. 2.8182201
# 5000631507  4119.6895 .. 4317.417 ...   3.4576697 .. -5.871444
# 5001043038  3834.1453 .. 4032.718 ... -0.04856968 .. 10.959146

# %%
im_array_random = fileh.root.FiberImages.read_coordinates(sel_random, 'im_array')

# %% [markdown]
# # Get Single Fiber cutouts for the four brightest fibers:

# %% [markdown]
# The 'im_array' column consists of fiber cutouts of the 4 brightest fibers

# %%
# plot each fiber for 4th object in example table
height=9

detectid = obj_data['detectid']
wave = obj_data['im_wave']
im_sum = obj_data['im_sum'] # this is the 2D summed image, 1st dim is height in fiber dims, 2nd dim is wave dim
im_array = obj_data['im_array'] # this is the 4 brightest fibers, 1st dim is fibers, 2nd dim is fiber dims, 3rd is wavelength
for im_i in np.arange(0,4):
    zscale = ZScaleInterval(contrast=0.5,krej=2.5)
    vmin, vmax = zscale.get_limits(values=im_array[im_i])
    plt.figure(figsize=(12,4))
    plt.title(str(detectid))
    plt.imshow(im_array[im_i],vmin=vmin, vmax=vmax,extent=[wave[0], wave[-1], -int(height/2.), int(height/2.)], origin="lower",cmap=plt.get_cmap('gray'),interpolation="none")
    plt.show()

# %% [markdown]
# ## Get the HSC 'r' band image if available

# %%
phot_image_table = Table(fileh.root.PhotImages.read_where('detectid == detectid_obj'))

# %%
#Loop over the images
height=9
for row in phot_image_table:
    detectid = row['detectid']
    im_phot = row['im_phot'] # this is the r-band image
    zscale = ZScaleInterval(contrast=0.5,krej=2.5)
    vmin, vmax = zscale.get_limits(values=im_phot)
    plt.figure()
    plt.title(str(detectid))
    plt.imshow(im_phot,vmin=vmin, vmax=vmax,extent=[-15, 15, -15, 15], origin="lower",cmap=plt.get_cmap('gray'),interpolation="none")
    plt.show()

# %% [markdown]
# ## Get the Detection Spectrum

# %% [markdown]
# The 1D aperture Summed Spectrum is also contained in this file

# %%
spec_table = Table(fileh.root.Spec1D.read_where(f'detectid == {detectid}'))

# %%
wave_rect = 2.0 * np.arange(1036) + 3470.0
plt.figure(figsize=(15,4))
plt.plot(wave_rect, spec_table['spec1D'][0]*10**-17 * u.erg / (u.cm ** 2 * u.s * u.AA))
plt.xlabel('wavelength (AA)')
plt.ylabel('spec 10**-17 ergs/s/cm^2/AA')
plt.title(detectid_obj)
plt.xlim(3550,5500)
plt.axhline(0, color='k')

# %% [markdown]
# ### make simulated data:

# %% [markdown]
# ## PLEASE CLOSE THE H5 FILE WHEN DONE

# %% [markdown]
# When done with an h5 file you should close it:

# %%
fileh.close()
